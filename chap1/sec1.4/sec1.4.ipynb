# %% [markdown]
# ### Differential Equations and Linear Algebra | Gilbert Strang | Solutions and Code by David A. Lee
# ### Chapter 1: First Order Equations
# #### Section 1.4: Four Particular Solutions

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

# %% [markdown]
# 11. Find a formula for $y(t)$ with $y(0) = 1$ and draw its graph. What is $y_{\infty}$?
#
# (a) $y ′ + 2y = 6$
#
# (b) $y ′ + 2y = −6$

# %%
t = np.arange(-0.5,5,0.01)
y1 = -2*np.exp(-2*t) + 3
y2 = 4*np.exp(-2*t) - 3

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y1, linewidth=2, color='#00ff9f', label="$y(t) = -2e^{-2t} + 3$")
plt.plot(t,y2, linewidth=2, color='#ff008d', label="$y(t) = 4e^{-2t} - 3$")
plt.hlines(-3, xmin=-0.5, xmax=5, linestyle="dotted", linewidth=2, color='white')
plt.hlines(3, xmin=-0.5, xmax=5, linestyle="dotted", linewidth=2, color='white')
plt.xlim(-0.5,5)
plt.ylim(-4,4)
plt.yticks(np.arange(-3,3.1,3))
plt.minorticks_off()
plt.legend(loc= 'right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex11.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 13. If a drip feeds $q = 0.3$ grams per minute into your arm, and your body eliminates the drug at the rate $6y$ grams per minute, what is the steady state concentration $y_\infty$? Then $in = out$ and $y_\infty$ is constant. Write a differential equation for $Y = y - y_\infty$.

# %%
t = np.arange(0,2,0.01)
y = -0.05*(np.exp(-6*t) - 1)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='#FF0040', label="$y(t) = -0.05e^{-6t} + 0.05$")
plt.xlim(0,2)
plt.ylim(0,0.07)
#plt.yticks(np.arange(0, 0.07, 0.06))
plt.xticks(np.arange(0, 2.1, 0.5))
plt.minorticks_off()
plt.legend(loc= 'upper right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex13.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 14. Why is $y_\infty$ the same for $y′ + y = H (t − 2)$ and $y′ + y = H (t − 10)$?

# %%
y_init = 1

t = np.arange(0,20,0.01)

y1 = np.exp(-t)*y_init - (np.exp(2 - t) - 1)
y2 = np.exp(-t)*y_init - (np.exp(10 - t) - 1)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y1, linewidth=2, color='#6074A1', label="$y(t) = e^{-t} y(0) - (e^{2-t} - 1)$")
plt.plot(t,y2, linewidth=2, color='#899B5F', label="$y(t) = e^{-t} y(0) - (e^{10-t} - 1)$")
plt.hlines(1, xmin=0, xmax=20, linestyle="dotted", linewidth=2, color='white')
plt.text(10, 1.1, '$\lim_{t \\rightarrow \infty} y(t) = 1$ when $y(0) = 1$', ha='center', va='center', fontsize=12)
plt.xlim(0,20)
plt.ylim(0,2)
plt.yticks(np.arange(0, 2.1, 1))
plt.xticks(np.arange(0, 21, 10))
plt.minorticks_off()
plt.legend(loc= 'upper right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex14.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 15. Draw the ramp function that solves $y′ = H (t − T)$ with $y(0) = 2$.

# %%
y_init = 1
T = 3

t1 = np.arange(0,3,0.01)
t2 = np.arange(3,6,0.01)

y1 = 2*np.ones(len(t1))
y2 = 2 + t2 - T

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=2, color='#F8BB3D')
plt.plot(t2,y2, linewidth=2, color='#F8BB3D')
plt.vlines(3, ymin=0, ymax=2, linestyle="dotted", linewidth=2, color='white')
plt.text(1.5, 2.5, '$y(t) = 2 + R(t - T)$', ha='center', va='center', fontsize=16)
plt.xlim(0,6)
plt.ylim(0,6)
plt.yticks(np.arange(0, 6.1, 2))
plt.xticks(np.arange(0, 6, 3), [0, "$T$"])
plt.minorticks_off()
plt.savefig('chap1sec1.4ex15.eps', format='eps')
plt.show()
# Out:
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 16. Find $y_n (t)$ and $y_p (t)$ as in equation (10), with step function inputs starting at $T = 4$.
#
# (a) $y′ − 5y = 3H (t − 4)$
#
# (b) $y′ + y = 7H (t − 4)$
#
# (What is $y_\infty$ ?)

# %%
t = np.arange(0,0.5,0.01)
inits = [i1, i2, i3, i4, i5] = [i for i in range(1,6)]

colors = ['#ff0000','#ffa500','#ffff00','#00ff00','#0000ff']

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
for i, c in zip(inits, colors):
    y1 = np.exp(5*t)*i + (3/5)*(np.exp(5*(t - 4)) - 1)
    plt.plot(t,y1, linewidth=2, color=c, label='$y(0) = {}$'.format(i))
plt.text(0.51, 4, '$y(t) = e^{5t} y(0) + \\frac{3}{5} (e^{5(t-4)} - 1)$', ha='center', va='center', fontsize=13.5)
plt.xlim(0,0.7)
plt.ylim(0,6)
plt.yticks(np.arange(0, 6.1, 2))
plt.minorticks_off()
plt.legend(loc= 'lower right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex16a.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %%
t = np.arange(0,100,0.01)
inits = [i1, i2, i3, i4, i5] = [i for i in np.arange(100,600,100)]

colors = ['#ff0000','#ffa500','#ffff00','#00ff00','#0000ff']

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
for i, c in zip(inits, colors):
    y2 = np.exp(-t)*i - 7*(np.exp(-(t - 4)) - 1)
    plt.plot(t,y2, linewidth=2, color=c, label='$y(0) = {}$'.format(i))
plt.hlines(7, xmin=3, xmax=10, linestyle="dotted", linewidth=2, color='white')
plt.text(8, 9, '$y(t) = e^{-t} y(0) - 7 (e^{-(t-4)} - 1)$', ha='center', va='center', fontsize=13.5)
plt.xlim(3,10)
plt.ylim(-10,15)
plt.yticks([-10, 0, 7, 10], ["-10", "0", "$y_\infty = 7$","10"], fontsize=14)
plt.minorticks_off()
plt.legend(loc= 'lower right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex16b.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 17. Suppose the step function turns on at $T = 4$ and off at $T = 6$. Then $q(t) = H(t − 4) − H(t − 6)$. Starting from $y(0) = 0$, solve $y′ + 2y = q(t)$. What is $y_\infty$?

# %%
y_init = 0

t1 = np.arange(0,4,0.01)
t2 = np.arange(4,6,0.01)
t3 = np.arange(6,15,0.01)

y1 = 0*np.ones(len(t1))
y2 = -(1/2)*(np.exp(-2*(t2 - 4)) - 1)
y3 = -(1/2)*(np.exp(-2*(t3 - 4)) - np.exp(-2*(t3 - 6)))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=2, linestyle='solid', color='#F47B30', label='$y(t) = 0$', zorder=3, clip_on=False)
plt.plot(t2,y2, linewidth=2, linestyle='dotted', color='#F47B30', label='$y(t) = -\\frac{1}{2}(e^{-2(t-4)} - 1)$', zorder=3, clip_on=False)
plt.plot(t3,y3, linewidth=2, linestyle='dashdot', color='#F47B30', label='$y(t) = -\\frac{1}{2}(e^{-2(t-4)} - e^{-2(t-6)})$', zorder=3, clip_on=False)
plt.vlines(4, ymin=0, ymax=10, linestyle="dotted", linewidth=2, color='white')
plt.vlines(6, ymin=0, ymax=10, linestyle="dotted", linewidth=2, color='white')
plt.xlim(0,15)
plt.ylim(0,1)
plt.yticks(np.arange(0, 1.1, 0.5))
plt.xticks([0, 4, 5, 6, 10, 15], ["", "Turn-on, $t = 4$", "", "Turn-off, $t = 6$", "", ""], rotation=30, ha='right', fontsize=14)
plt.minorticks_off()
plt.legend(loc= 'upper right', frameon=True, fontsize=12)
plt.savefig('chap1sec1.4ex17.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 18. Suppose $y′ = H(t − 1) + H(t − 2) + H(t − 3)$, starting at $y(0) = 0$. Find $y(t)$.

# %%
y_init = 0

t1 = np.arange(0,1,0.01)
t2 = np.arange(1,2,0.01)
t3 = np.arange(2,3,0.01)
t4 = np.arange(3,4,0.01)

y1 = 0*np.ones(len(t1))
y2 = t2 - 1
y3 = 2*t3 - 3
y4 = 3*(t4 - 2)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=2, color='#FBE890', label='$y(t) = 0$', zorder=3, clip_on=False)
plt.plot(t2,y2, linewidth=2, color='#BBA53D', label='$y(t) = t - 1$', zorder=3, clip_on=False)
plt.plot(t3,y3, linewidth=2, color='#DAB000', label='$y(t) = 2t - 3$', zorder=3, clip_on=False)
plt.plot(t4,y4, linewidth=2, color='#F3C305', label='$y(t) = 3(t - 2)$')
plt.vlines(2, ymin=0, ymax=1, linestyle="dotted", linewidth=2, color='white')
plt.vlines(3, ymin=0, ymax=3, linestyle="dotted", linewidth=2, color='white')
plt.xlim(0,4)
plt.ylim(0,4)
plt.yticks(np.arange(0, 4.1, 1))
plt.xticks(np.arange(0, 4.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex18.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 19. (a) $\displaystyle \int^t_0 \delta (T-2) \, dT$

# %%
x_solid, y_solid = [2], [1]
x_hollow, y_hollow = [2], [0]

t1 = np.arange(0,2,0.01)
t2 = np.arange(2,4,0.01)

y1 = 0*np.ones(len(t1))
y2 = np.ones(len(t2))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=3, color='white', label="$a(t) = H(T-2)$")
plt.plot(t2,y2, linewidth=3, color='white')
plt.scatter(x_hollow, y_hollow, s=40, facecolors='k', edgecolors='white', zorder=2, clip_on=False) # hollow points
plt.scatter(x_solid, y_solid, s=40, facecolors='white', edgecolors='white', zorder=2, clip_on=False) # solid points
plt.vlines(2, ymin=0, ymax=1, linestyle="dotted", linewidth=3, color='white', zorder=1, clip_on=False)
plt.xlim(0,4)
plt.ylim(-1,2)
plt.yticks(np.arange(-1, 2.1, 1))
plt.xticks(np.arange(0, 4.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex19a.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 19. (b) $\displaystyle \int^t_0 (\delta (T - 2) - \delta (T - 3)) \, dT$

# %%
x_solid, y_solid = [2,3], [1,0]
x_hollow, y_hollow = [2,3], [0,1]

t1 = np.arange(0,2,0.01)
t2 = np.arange(2,3,0.01)
t3 = np.arange(3,4,0.01)

y1 = 0*np.ones(len(t1))
y2 = np.ones(len(t2))
y3 = 0*np.ones(len(t3))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=3, color='white', label="$b(t) = H(T - 2) - H(T - 3)$")
plt.plot(t2,y2, linewidth=3, color='white')
plt.plot(t3,y3, linewidth=3, color='white')
plt.scatter(x_hollow, y_hollow, s=40, facecolors='k', edgecolors='white', zorder=2, clip_on=False) # hollow points
plt.scatter(x_solid, y_solid, s=40, facecolors='white', edgecolors='white', zorder=2, clip_on=False) # solid points
plt.vlines(2, ymin=0, ymax=1, linestyle="dotted", linewidth=3, color='white', zorder=1, clip_on=False)
plt.vlines(3, ymin=0, ymax=1, linestyle="dotted", linewidth=3, color='white', zorder=1, clip_on=False)
plt.xlim(0,4)
plt.ylim(-1,2)
plt.yticks(np.arange(-1, 2.1, 1))
plt.xticks(np.arange(0, 4.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex19bi.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %%
t = np.arange(0,4,0.01)

y = 0*np.ones(len(t))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=3, color='white')
plt.vlines(2, ymin=0, ymax=2, linestyle="solid", linewidth=3, color='white', label="$\delta (T - 2)$")
plt.vlines(3, ymin=-2, ymax=0, linestyle="dotted", linewidth=3, color='white', label="$-\delta (T - 3)$")
plt.text(1.5, -0.3, "$\delta (T - 2) - \delta (T - 3)$", ha='center', va='center', fontsize=16)
plt.xlim(0,4)
plt.ylim(-2,2)
plt.yticks(np.arange(-2, 2.1, 1))
plt.xticks(np.arange(0, 4.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex19b.eps', format='eps')
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\david\AppData\Local\Temp\ipykernel_7836\1144393688.py:8: SyntaxWarning: invalid escape sequence '\d'
#   plt.vlines(2, ymin=0, ymax=2, linestyle="solid", linewidth=3, color='white', label="$\delta (T - 2)$")
# C:\Users\david\AppData\Local\Temp\ipykernel_7836\1144393688.py:9: SyntaxWarning: invalid escape sequence '\d'
#   plt.vlines(3, ymin=-2, ymax=0, linestyle="dotted", linewidth=3, color='white', label="$-\delta (T - 3)$")
# C:\Users\david\AppData\Local\Temp\ipykernel_7836\1144393688.py:10: SyntaxWarning: invalid escape sequence '\d'
#   plt.text(1.5, -0.3, "$\delta (T - 2) - \delta (T - 3)$", ha='center', va='center', fontsize=16)
# ...

# %% [markdown]
# 21. The solution to $y ′ = 2y + δ (t − 3)$ jumps up by $1$ at $t = 3$. Before and after $t = 3$, the delta function is zero and y grows like $e^{2t}$. Draw the graph of $y(t)$ when
#
# (a) $y(0) = 0$ and
#
# (b) $y(0) = 1$.
#
# Write formulas for $y(t)$ before and after $t = 3$.

# %%
x_solid, y_solid = [3], [1]
x_hollow, y_hollow = [3], [0]

t1 = np.arange(0,3,0.01)
t2 = np.arange(3,5,0.01)

ay1 = 0*np.ones(len(t1))
ay2 = np.exp(2*(t2-3))

by1 = np.exp(2*t1)
by2 = np.exp(2*t2) + np.exp(2*(t2-3))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,ay1, linewidth=3, color='#96709F', label="$y(0) = 0$", zorder=3, clip_on=False)
plt.plot(t2,ay2, linewidth=3, color='#96709F')
plt.plot(t1,by1, linewidth=3, color='#CFE2F7', label="$y(0) = 1$")
plt.plot(t2,by2, linewidth=3, color='#CFE2F7')
plt.scatter(x_hollow, y_hollow, s=40, facecolors='k', edgecolors='#96709F', zorder=3, clip_on=False) # hollow points
plt.scatter(x_solid, y_solid, s=40, facecolors='#96709F', edgecolors='#96709F', zorder=2, clip_on=False) # solid points
plt.vlines(3, ymin=0, ymax=1, linestyle="dotted", linewidth=3, color='#96709F', zorder=2, clip_on=False)
plt.xlim(0,5)
plt.ylim(0,10)
plt.yticks(np.arange(0, 10.1, 5))
plt.xticks(np.arange(0, 5.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper center', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex21.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 22. Solve these differential equations starting at $y (0) = 2$:
#
# (a) $y ′ − y = \delta (t − 2)$
#
# (b) $y ′ + y = \delta (t − 2)$
#
# (What is $y_\infty$?)

# %%
x_solid, y_solid = [2], [2*np.exp(-2) + 1]
x_hollow, y_hollow = [2], [2*np.exp(-2)]

t1 = np.arange(0,2,0.01)
t2 = np.arange(2,8,0.01)

ay1 = 2*np.exp(t1)
ay2 = 2*np.exp(t2) + np.exp(t2 - 2)

by1 = 2*np.exp(-t1)
by2 = 2*np.exp(-t2) + np.exp(-(t2 - 2))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,ay1, linewidth=3, color='#73DCA1', label="$y(t) = 2e^2 + H (t - 2) e^{t - 2}$")
plt.plot(t2,ay2, linewidth=3, color='#73DCA1')
plt.plot(t1,by1, linewidth=3, color='#68BCC5', label="$y(t) = 2e^{-2} + H (t - 2) e^{-(t - 2)}$")
plt.plot(t2,by2, linewidth=3, color='#68BCC5')
plt.scatter(x_hollow, y_hollow, s=40, facecolors='k', edgecolors='#68BCC5', zorder=3, clip_on=False) # hollow points
plt.scatter(x_solid, y_solid, s=40, facecolors='#68BCC5', edgecolors='#68BCC5', zorder=2, clip_on=False) # solid points
plt.vlines(2, ymin=2*np.exp(-2), ymax=2*np.exp(-2) + 1, linestyle="dotted", linewidth=3, color='#68BCC5', zorder=2, clip_on=False)
plt.xlim(0,8)
plt.ylim(0,10)
plt.yticks(np.arange(0, 10.1, 5))
plt.xticks(np.arange(0, 8.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex22.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 23. Solve $dy/dt = H (t − 1) + \delta (t − 1)$ starting from $y (0) = 0$: jump and ramp.

# %%
x_solid, y_solid = [1], [1]
x_hollow, y_hollow = [1], [0]

t1 = np.arange(0,1,0.01)
t2 = np.arange(1,4,0.01)

y1 = 0*np.ones(len(t1))
y2 = t2

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=3, color='#FFA70B', label="$y(t) = R(t-1) + H(t-1)$", zorder=3, clip_on=False)
plt.plot(t2,y2, linewidth=3, color='#FFA70B')
plt.scatter(x_hollow, y_hollow, s=40, facecolors='k', edgecolors='#FFA70B', zorder=3, clip_on=False) # hollow points
plt.scatter(x_solid, y_solid, s=40, facecolors='#FFA70B', edgecolors='#FFA70B', zorder=2, clip_on=False) # solid points
plt.vlines(1, ymin=0, ymax=1, linestyle="dotted", linewidth=3, color='#FFA70B', zorder=2, clip_on=False)
plt.xlim(0,4)
plt.ylim(0,4)
plt.yticks(np.arange(0, 4.1, 1))
plt.xticks(np.arange(0, 4.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex23.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 25. Which $q$ and $y(0)$ in $y′ − 3y = q(t)$ produce the step solution $y(t) = H(t-1)$?

# %%
x_hollow, y_hollow = [1], [-3]

t1 = np.arange(0,1,0.01)
t2 = np.arange(1,5,0.01)

y1 = 0*np.ones(len(t1))
y2 = -3*np.ones(len(t2))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=3, color='#E0E0E0', label="$y(t) = R(t-1) + H(t-1)$", zorder=3, clip_on=False)
plt.plot(t2,y2, linewidth=3, color='#E0E0E0', zorder=3, clip_on=False)
plt.scatter(x_hollow, y_hollow, s=40, facecolors='k', edgecolors='#E0E0E0', zorder=3, clip_on=False) # hollow points
plt.vlines(1, ymin=0, ymax=2, linestyle="solid", linewidth=3, color='#E0E0E0', zorder=2, clip_on=False)
plt.xlim(0,5)
plt.ylim(-3,2)
plt.yticks(np.arange(-3, 2.1, 1))
plt.xticks(np.arange(0, 5.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex25.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 26. Solve these equations $y′ − ay = Qe^{ct}$ as in (19), starting from $y(0) = 2$:
#
# (a) $y′ − y = 8e^{3t}$
#
# (b) $y′ + y = 8e^{−3t}$
#
# (What is $y_\infty$?)

# %%
t = np.arange(0,5,0.01)

y1 = -2*np.exp(t) + 4*np.exp(3*t)
y2 = 6*np.exp(-t) - 4*np.exp(-3*t)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y1, linewidth=3, color='#57A639', label="$y(t) = -2e^t + 4e^{3t}$")
plt.plot(t,y2, linewidth=3, color='#C6A664', label="$y(t) = 6e^{-t} - 4e^{-3t}$")
plt.xlim(0,5)
plt.ylim(0,10)
plt.yticks(np.arange(0, 10.1, 2))
plt.xticks(np.arange(0, 5.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex26.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 27. When $c = 2.01$ is very close to $a = 2$, solve $y ′ − 2y = e^{ct}$ starting from $y(0) = 1$. This is resonance as in equation (20). By hand or computer, draw the graph of $y(t)$.

# %%
c = 2.01

inits = [c1, c2, c3, c4, c5] = [i for i in np.arange(2.1,3.1,0.2)]
colors = ['#ff0000','#ffa500','#ffff00','#00ff00','#0000ff']

t = np.arange(0,5,0.01)

y = ((c-3)/(c-2))*np.exp(2*t) + (1/(c-2))*np.exp(c*t)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='white', label="$c = 2.01$")
for i, col in zip(inits, colors):
    y1 = ((i-3)/(i-2))*np.exp(2*t) + (1/(i-2))*np.exp(i*t)
    plt.plot(t,y1, linewidth=2, color=col, label='$c = {}$'.format(round(i, 1)))
plt.text(0.5,3, "$y(t) = \\frac{c-3}{c-2} e^{2t} + \\frac{1}{c-2} e^{ct}$", fontsize=16)
plt.xlim(0,1)
plt.ylim(0,10)
plt.yticks(np.arange(0, 10.1, 1))
plt.xticks(np.arange(0, 1.1, 0.5))
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=14)
plt.savefig('chap1sec1.4ex27.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 28. When $c = 2$ is exactly equal to $a = 2$, solve $y′ − 2y = e^{2t}$ starting from $y(0) = 1$. This resonance is as in equation (20). By hand or computer, draw the graph of $y(t)$.

# %%
t = np.arange(0,5,0.01)

y = np.exp(2*t) + t*np.exp(2*t)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='#C35831', label="$y(t) = e^{2t} + te^{2t}$")
plt.xlim(0,1)
plt.ylim(0,10)
plt.yticks(np.arange(0, 10.1, 5))
plt.xticks(np.arange(0, 1.1, 1))
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.4ex28.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.
