# %% [markdown]
# ### Differential Equations and Linear Algebra | Gilbert Strang | Solutions and Code by David A. Lee
# ### Chapter 1: First Order Equations
# #### Section 1.7: The Logistic Equation

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

# %% [markdown]
# 1. If $y(0) = a/2b$, the halfway point on the $S$-curve is at $t = 0$. Show that $d = b$ and $y(t) = \frac{a}{de^{-at} + b} = \frac{a}{b} \frac{1}{e^{-at} + 1}$. Sketch the curve from $y_{-\infty} = 0$ to $y_{\infty} = a/b$.

# %%
t = np.arange(-5,5,0.01)
a, b = 1, 1
y = (a/b)*(1/(np.exp(-a*t) + 1))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='#00ff9f', label="$y(t) = \\frac{a}{b} \\frac{1}{e^{-at} + 1}$")
plt.scatter(0,1/2, s=40, facecolors='white', edgecolors='white', zorder=2, clip_on=False)
plt.text(1/2,1/2, '$y(0) = \\frac{a}{2b}$', fontsize=18)
plt.xlim(-5,5)
plt.ylim(0,1)
plt.xticks(np.arange(-4,4.1,4), ['$-\\infty \leftarrow t$', '0', '$t \\rightarrow \\infty$'], fontsize=18)
plt.yticks(np.arange(0,1.1,0.5), ['0', '$\\frac{a}{2b}$', '$\\frac{a}{b}$'], fontsize=18)
plt.hlines(1/2, xmin=-5, xmax=0, linestyle="dotted", linewidth=2, color='white')
plt.vlines(0,ymin=0, ymax=1/2, linestyle="dotted", linewidth=2, color='white')
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=20)
plt.savefig('chap1sec1.7ex1.eps', format='eps')
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\david\AppData\Local\Temp\ipykernel_13236\1704405583.py:12: SyntaxWarning: invalid escape sequence '\l'
#   plt.xticks(np.arange(-4,4.1,4), ['$-\\infty \leftarrow t$', '0', '$t \\rightarrow \\infty$'], fontsize=18)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 7. $y ′ = y − y^2$ is solved by $y(t) = 1/(de^{-t} + 1)$. This is an $S$-curve when $y(0) = 1/2$ and $d = 1$. But show that $y(t)$ is very different if $y(0) > 1$ or if $y(0) < 0$.
#
# If $y(0) = 2$ then $d = 1/2 − 1 = − 1/2$ . Show that $y(t) \rightarrow 1$ from above.
#
# If $y(0) = −1$ then $d = −1 − 1 = −2$. At what time $T$ is $y(T) = −\infty$?

# %%
t = np.arange(-0.69,1,0.001)
d = -1/2
y = 1/(d*np.exp(-t) + 1)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='#89c7bc', label="$y(t) = \\frac{1}{-\\frac{1}{2}e^{-1} + 1}$")
plt.hlines(1, xmin=-1, xmax=1, linestyle="dotted", linewidth=2, color='white')
plt.text(0.4,10,'$y(t) = 1$', fontsize=20)
plt.xlim(-1,1)
plt.ylim(-5,100)
plt.minorticks_off()
plt.legend(loc= 'upper right', frameon=True, fontsize=20)
plt.savefig('chap1sec1.7ex7a.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %%
t = np.arange(-1,np.log(2),0.001)
d = -2
y = 1/(d*np.exp(-t) + 1)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='#f6ae0e', label="$y(t) = \\frac{1}{-2e^{-1} + 1}$")
plt.text(0.1,-60,'$T = \\ln(2)$', fontsize=20)
plt.vlines(np.log(2), ymin=-100, ymax=10, linestyle="dotted", linewidth=2, color='white')
plt.ylim(-100,10)
plt.minorticks_off()
plt.legend(loc= 'lower left', frameon=True, fontsize=20)
plt.savefig('chap1sec1.7ex7b.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 8. (recommended) Show those 3 solutions to $y ′ = y − y^2$ in one graph! They start from $y(0) = 1/2$ and $2$ and $−1$. The $S$-curve climbs from $12$ to $1$. Above that, $y(t)$ descends from $2$ to $1$. Below the $S$-curve, $y(t)$ drops from $−1$ to $−\infty$. Can you see $3$ regions in the picture? Dropin curves above $y = 1$ and $S$-curves sandwiched between $0$ and $1$ and dropoff curves below $y = 0$.

# %%
t = np.arange(-5,10,0.01)

t21 = np.arange(-5,-np.log(2),0.01)
t22 = np.arange(-np.log(2),10,0.01)

t31 = np.arange(-5,-np.log(1/2),0.01)
t32 = np.arange(-np.log(1/2),10,0.01)

y1 = 1/(np.exp(-t) + 1)

y21 = 1/((-1/2)*np.exp(-t21) + 1)
y22 = 1/((-1/2)*np.exp(-t22) + 1)

y31 = 1/(-2*np.exp(-t31) + 1)
y32 = 1/(-2*np.exp(-t32) + 1)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y1, linewidth=2, color='#FE7176', label="$y(t) = \\frac{1}{e^{-1} + 1}$")
plt.plot(t21,y21, linewidth=2, color='#FFCD67', label="$y(t) = \\frac{1}{(-1/2)e^{-1} + 1}$")
plt.plot(t22,y22, linewidth=2, color='#FFCD67')
plt.plot(t31,y31, linewidth=2, color='#38B6C4', label="$y(t) = \\frac{1}{-2e^{-1} + 1}$")
plt.plot(t32,y32, linewidth=2, color='#38B6C4')
plt.text(-4,2,'$y = 1$', fontsize=16)
plt.text(-4,-1.5,'$y = 0$', fontsize=16)
plt.hlines(1, xmin=-5, xmax=10, linestyle="dotted", linewidth=2, color='white')
plt.hlines(0, xmin=-5, xmax=10, linestyle="dotted", linewidth=2, color='white')
plt.xlim(-5,10)
plt.ylim(-8,8)

plt.minorticks_off()
plt.legend(loc= 'lower right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.7ex8.eps', format='eps')
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_15624\393833624.py:12: RuntimeWarning: divide by zero encountered in divide
#   y22 = 1/((-1/2)*np.exp(-t22) + 1)
# C:\Users\david\AppData\Local\Temp\ipykernel_15624\393833624.py:15: RuntimeWarning: divide by zero encountered in divide
#   y32 = 1/(-2*np.exp(-t32) + 1)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 9. Graph $f(y) = y − y^2$ to see the unstable steady state $Y = 0$ and the stable $Y = 1$. Then graph $f(y) = y − y^2 − 2/9$ with harvesting $h = 2/9$. What are the steady states $Y_1$ and $Y_2$? The 3 regions in Problem 8 now have $Z$-curves above $y = 2/3$, $S$-curve sandwiched between $1/3$ and $2/3$, dropoff curves below $y = 1/3$.

# %%
y = np.arange(-0.2,1.2,0.01)

func1 = y - np.square(y)
func2 = y - np.square(y) - 2/9

horiz = [0, 1/3, 2/3, 1]
vert = [0, 0, 0, 0]

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(y,func1, linewidth=2, color='#E33CC7', label="$f(y) = y - y^2$")
plt.plot(y,func2, linewidth=2, color='#F54D28', label="$f(y) = y - y^2 - 2/9$")
plt.scatter(horiz,vert, s=40, facecolors='white', edgecolors='white', zorder=2, clip_on=False)
plt.hlines(0, xmin=-0.2, xmax=1.2, linestyle="dotted", linewidth=2, color='white', zorder=0)
plt.text(-0.1,0.015,'$Y = 0$', horizontalalignment='center', fontsize=14)
plt.text(1.1,0.015,'$Y = 1$', horizontalalignment='center', fontsize=14)
plt.text(1.1,0.015,'$Y = 1$', horizontalalignment='center', fontsize=14)
plt.text(0.2,0.015,'$Y_1 = 1/3$', horizontalalignment='center', fontsize=14)
plt.text(0.8,0.015,'$Y_2 = 2/3$', horizontalalignment='center', fontsize=14)
plt.xlim(-0.2,1.2)
plt.minorticks_off()
plt.legend(loc= 'lower center', frameon=True, fontsize=16)
plt.savefig('chap1sec1.7ex9.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 11. $y′ = y − y^2 − \frac{1}{4} = − (y − \frac{1}{2})^2$ shows critical harvesting with a double steady state at $y = Y = \frac{1}{2}$. The layer of $S$-curves shrinks to that single line. Sketch a dropin curve that starts above $y(0) = \frac{1}{2}$ and a dropoff curve that starts below $y(0) = \frac{1}{2}$.

# %%
t = np.arange(-10,10,0.01)

t11 = np.arange(-10,-2,0.01)
t12 = np.arange(-2,10,0.01)

t21 = np.arange(-10,2,0.01)
t22 = np.arange(2,10,0.01)

y = np.ones(len(t))*(1/2)

y01 = 1
y11 = (y01 - 1/2)/(y01*t11 - t11/2 + 1) + 1/2
y12 = (y01 - 1/2)/(y01*t12 - t12/2 + 1) + 1/2

y02 = 0
y21 = (y02 - 1/2)/(y02*t21 - t21/2 + 1) + 1/2
y22 = (y02 - 1/2)/(y02*t22 - t22/2 + 1) + 1/2

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='#ff1111', label="$y(0) = \\frac{1}{2}$")
plt.plot(t11,y11, linewidth=2, color='#f2e900', label="$y(0) = 1$")
plt.plot(t12,y12, linewidth=2, color='#f2e900')
plt.plot(t21,y21, linewidth=2, color='#007aff', label="$y(0) = 0$")
plt.plot(t22,y22, linewidth=2, color='#007aff')
plt.text(-7.5,1,'$y(t) = 1/2$', fontsize=16)
plt.xlim(-10,10)
plt.ylim(-5,5)

plt.minorticks_off()
plt.legend(loc= 'lower right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.7ex11.eps', format='eps')
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_22284\1300668744.py:13: RuntimeWarning: divide by zero encountered in divide
#   y12 = (y01 - 1/2)/(y01*t12 - t12/2 + 1) + 1/2
# C:\Users\david\AppData\Local\Temp\ipykernel_22284\1300668744.py:17: RuntimeWarning: divide by zero encountered in divide
#   y22 = (y02 - 1/2)/(y02*t22 - t22/2 + 1) + 1/2
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 13.  With overharvesting, every curve $y(t)$ drops to $−\infty$. There are no steady states. Solve $Y − Y^2 − h = 0$ (quadratic formula) to find only complex roots if $4h > 1$. The solutions for $h = \frac{5}{4}$ are $y(t) = 12 − \tan(t + C)$. Sketch that dropoff if $C = 0$. Animal populations don’t normally collapse like this from overharvesting.

# %%
t = np.arange(0,np.pi/2,0.01)
y = 1/2 - np.tan(t)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='#ff1111', label="$y(t) = \\frac{1}{2} + \\tan(t)$")
plt.hlines(0, xmin=0, xmax=2, linestyle="dotted", linewidth=2, color='white', zorder=0)
plt.text(0.1, -1, '$y(t) = 0$', fontsize=16)
plt.xlim(0,2)
plt.xticks([0, np.pi/2], ['$0$', '$\\pi/2$'])
plt.ylim(-10,1)
plt.yticks([-10,0], ['$-10$', '$0$'])

plt.minorticks_off()
plt.legend(loc= 'lower left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.7ex13.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 15. The threshold equation is the logistic equation backward in time:
# $$
#     -\frac{dy}{dt} = ay − by^2
# $$
# is the same as
#
# $$
#     \frac{dy}{dt} = −ay + by^2
# $$
# Now $Y = 0$ is the stable steady state. $Y = a/b$ is the unstable state (why?). If $y(0)$ is below the threshold $a/b$ then $y(t) → 0$ and the species
# will die out.
#
# Graph $y(t)$ with $y(0) < a/b$ (reverse $S$-curve). Then graph $y(t)$ with $y(0) > a/b$.

# %%
t = np.arange(-5,5,0.01)

y01 = 0.5
y02 = 1.5
a = 1
b = 1
d1 = 1/y01 - b/a
d2 = 1/y02 - b/a

t1 = np.arange(-5,np.log(3),0.01)
t2 = np.arange(np.log(3),5,0.01)

y1 = 1/(d1*np.exp(a*t) + b)

y21 = 1/(d2*np.exp(a*t1) + b)
y22 = 1/(d2*np.exp(a*t2) + b)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y1, linewidth=2, color='#ffcc00', label="$y(0) < a/b$")
plt.plot(t1,y21, linewidth=2, color='#ff00ff', label="$y(0) > a/b$")
plt.plot(t2,y22, linewidth=2, color='#ff00ff')
plt.text(2,1.1,'$y = a/b = 1$', fontsize=16)
plt.text(-3,0.1,'$y = 0$', fontsize=16)
plt.hlines(1, xmin=-5, xmax=10, linestyle="dotted", linewidth=2, color='white')
plt.hlines(0, xmin=-5, xmax=10, linestyle="dotted", linewidth=2, color='white')
plt.xlim(-5,5)
plt.ylim(-1,2)

plt.minorticks_off()
plt.legend(loc= 'lower left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.7ex15.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 17. (a) Find the steady states of the Gompertz equation $dy/dt = y(1 − \ln (y))$.
#
# (b) Show that $z = \ln (y)$ satisfies the linear equation $dz/dt = 1 − z$.
#
# (c) The solution $z(t) = 1 + e^{-t} (z(0) − 1)$ gives what formula for $y(t)$ from $y(0)$?

# %%
t = np.arange(-3,7,0.01)

y01 = np.exp(1) - 1
y02 = np.exp(1)
y03 = np.exp(1) + 1

y1 = np.exp(1 + np.exp(-t)*(np.log(y01) - 1))
y2 = np.exp(1 + np.exp(-t)*(np.log(y02) - 1))
y3 = np.exp(1 + np.exp(-t)*(np.log(y03) - 1))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y1, linewidth=2, color='#FF6F61', label="$y(0) < e$")
plt.plot(t,y2, linewidth=2, linestyle="dotted", color='white', label="$y(0) = e$")
plt.plot(t,y3, linewidth=2, color='#6667AB', label="$y(0) > e$")
plt.text(-2,3,'$y = e$', fontsize=16)
plt.xlim(-3,7)
plt.ylim(0,5)

plt.minorticks_off()
plt.legend(loc= 'lower right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.7ex17.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 20. $dy/dt = ay − y^3$ has how many steady states $Y$ for $a < 0$ and then $a > 0$? Graph those values $Y(a)$ to see a pitchfork bifurcation–new steady states suddenly appear as $a$ passes zero. The graph of $Y(a)$ looks like a pitchfork.

# %%
a = np.arange(-5,10,0.01)

y1 = np.sqrt(a)
y2 = 0*np.ones(len(a))
y3 = -np.sqrt(a)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(a,y1, linewidth=2, color='#009B77')
plt.plot(a,y2, linewidth=2, color='#009B77')
plt.plot(a,y3, linewidth=2, color='#009B77')
plt.vlines(0,ymin=-5, ymax=5, linewidth=2, linestyle="dotted")
plt.text(5,3.5, "$Y(a) = \\sqrt{a}$", fontsize=16)
plt.text(5,-4, "$Y(a) = -\\sqrt{a}$", fontsize=16)
plt.xlim(-5,10)
plt.xlabel("$a$", fontsize=16)
plt.ylim(-5,5)
plt.ylabel("$Y(a)$", fontsize=16)

plt.minorticks_off()
plt.savefig('chap1sec1.7ex20.eps', format='eps')
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_5584\1075077378.py:3: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(a)
# C:\Users\david\AppData\Local\Temp\ipykernel_5584\1075077378.py:5: RuntimeWarning: invalid value encountered in sqrt
#   y3 = -np.sqrt(a)
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 25. (a) Draw a function $f(y)$ so that $y(t)$ approaches $y(\infty) = 3$ from every $y(0)$.
#
# (b) Draw $f(y)$ so that $y(\infty) = 4$ if $y(0) > 0$ and $y(\infty) = −2$ if $y(0) < 0$.

# %%
# (a)

y = np.arange(-1,4,0.01)

fy = 3 - y

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(y,fy, linewidth=2, color='#98B4D4', zorder=4, label='$f(y) = 3 - y$')
plt.scatter(3,0, s=40, facecolors='white', edgecolors='white', zorder=5, clip_on=False)
plt.hlines(0, xmin=-1, xmax=4, linewidth=2, linestyle='dotted', zorder=1)
plt.vlines(0,ymin=-1, ymax=4, linewidth=2, linestyle="dotted", zorder=1)
plt.text(3,0.2, "$Y = 3$", fontsize=16)
plt.xlim(-1,4)
plt.xlabel("$y$", fontsize=16)
plt.ylim(-1,4)
plt.ylabel("$f(y)$", fontsize=16)

plt.minorticks_off()
plt.legend(loc= 'upper right', frameon=True, fontsize=16)
plt.savefig('chap1sec1.7ex25a.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %%
# (b)

y1 = np.arange(-4,-1,0.01)
y2 = np.arange(-1,2,0.01)
y3 = np.arange(2,5,0.01)

fy1 = -2 - y1
fy2 = y2
fy3 = 4 - y3

horiz = [-2,0,4]
vert = [0,0,0]

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(y1,fy1, linewidth=2, color='#98B4D4', zorder=4)
plt.plot(y2,fy2, linewidth=2, color='#98B4D4', zorder=4)
plt.plot(y3,fy3, linewidth=2, color='#98B4D4', zorder=4)
plt.scatter(horiz,vert, s=40, facecolors='white', edgecolors='white', zorder=5, clip_on=False)
plt.hlines(0, xmin=-4, xmax=5, linewidth=2, linestyle='dotted', zorder=1)
plt.vlines(0,ymin=-2, ymax=4, linewidth=2, linestyle="dotted", zorder=1)
plt.text(-2,0.1, "$Y = -2$", fontsize=16)
plt.text(0.2,-0.2, "$Y = 0$", fontsize=16)
plt.text(2.8,-0.2, "$Y = 4$", fontsize=16)
plt.xlim(-4,5)
plt.xlabel("$y$", fontsize=16)
plt.ylim(-1,2)
plt.ylabel("$f(y)$", fontsize=16)

plt.minorticks_off()
plt.savefig('chap1sec1.7ex25b.eps', format='eps')
plt.show()
# Out:
# Failed to find a Ghostscript installation.  Distillation step skipped.
