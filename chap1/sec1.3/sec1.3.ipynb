# %% [markdown]
# ### Differential Equations and Linear Algebra | Gilbert Strang | Solutions and Code by David A. Lee
# ### Chapter 1: First Order Equations
# #### Section 1.3: The Exponentials $e^t$ and $e^{at}$

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

# %% [markdown]
# 1. Set $t = 2$ in the infinite series for $e^2$. The sum must be $e$ times $e$, close to 7.39. How many terms in the series to reach a sum of 7? How many terms to pass 7.3?

# %%
t = 2

term1 = 1
term2 = 1 + t
term3 = 1 + t + (1/2)*np.power(t,2)
term4 = 1 + t + (1/2)*np.power(t,2) + (1/6)*np.power(t,3)
term5 = 1 + t + (1/2)*np.power(t,2) + (1/6)*np.power(t,3) + (1/24)*np.power(t,4)
term6 = 1 + t + (1/2)*np.power(t,2) + (1/6)*np.power(t,3) + (1/24)*np.power(t,4) + (1/120)*np.power(t,5)
term7 = 1 + t + (1/2)*np.power(t,2) + (1/6)*np.power(t,3) + (1/24)*np.power(t,4) + (1/120)*np.power(t,5) + (1/720)*np.power(t,6)

term7
# Out:
# 7.355555555555555

# %% [markdown]
# 2. Starting from $y(0) = 1$, find the solution to $dy/dt = y$ at time $t = 1$. Starting from that $y(1)$, solve $dy/dt = −y$ to time $t = 2$. Draw a rough graph of $y(t)$ from $t = 0$ to $t = 2$. What does this say about $e^{-1}$ times $e$?

# %%
t1 = np.arange(0,1,0.01)
t2 = np.arange(1,2,0.01)
y1 = np.exp(t1)
y2 = np.exp(2-t2)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=2, color='#f96363')
plt.plot(t2,y2, linewidth=2, color='#f96363')
plt.xticks(np.arange(0, 3, step=1), [0, 1, 2])
plt.xlim(0,2)
plt.ylim(0,)
plt.minorticks_off()
plt.savefig('chap1sec1.3ex2.eps', format='eps')
plt.show()
# Out:
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 3. Start with $y(0) = \$5000$. If this grows by $dy/dt = .02y$ until $t = 5$ and then jumps to $a = .04$ per year until $t = 10$, what is the account balance at $t = 10$?

# %%
t1 = np.arange(0,5,0.01)
t2 = np.arange(5,10.01,0.01)

initial1 = 5000
initial2 = 5000*np.exp(0.02*5) / np.exp(0.04*5)

y1 = initial1*np.exp(0.02*t1)
y2 = initial2*np.exp(0.04*t2)

y2t10 = initial2*np.exp(0.04*10)
print(y2t10)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=2, color='#ff008d')
plt.plot(t2,y2, linewidth=2, color='#ff008d')
plt.xlim(0,10)
plt.ylim(4750,)
plt.minorticks_off()
plt.savefig('chap1sec1.3ex3.eps', format='eps')
plt.show()
# Out:
# 6749.294037880017
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 4. Change Problem 3 to start with $\$5000$ growing at $dy/dt = .04y$ for the first five years. Then drop to $a = .02$ until $t = 10$. What is now the balance at $t = 10$?

# %%
t1 = np.arange(0,5,0.01)
t2 = np.arange(5,10.01,0.01)

initial1 = 5000
initial2 = 5000*np.exp(0.04*5) / np.exp(0.02*5)

y1 = initial1*np.exp(0.04*t1)
y2 = initial2*np.exp(0.02*t2)

y2t10 = initial2*np.exp(0.02*10)
print(y2t10)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=2, color='#ff008d')
plt.plot(t2,y2, linewidth=2, color='#ff008d')
plt.xlim(0,10)
plt.ylim(4750,)
plt.minorticks_off()
plt.savefig('chap1sec1.3ex4.eps', format='eps')
plt.show()
# Out:
# 6749.294037880015
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 11. In a one-year investment of $y(0) = \$100$, suppose the interest rate jumps from $6\%$ to $10\%$ after six months. Does the equivalent rate for a whole year equal $8\%$, or more than $8\%$, or less than $8\%$?

# %%
t1 = np.arange(0,6,0.01)
t2 = np.arange(6,12.01,0.01)
t3 = np.arange(0,12.01,0.01)

initial1 = 100
initial2 = 100*np.exp(0.06*6) / np.exp(0.1*6)

y1 = initial1*np.exp(0.06*t1)
y2 = initial2*np.exp(0.1*t2)
y3 = initial1*np.exp(0.08*t3)

y2t12 = initial2*np.exp(0.1*12)
print(y2t12)
y3t12 = initial1*np.exp(0.08*12)
print(y3t12)

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t1,y1, linewidth=2, color='#d14eea')
plt.plot(t2,y2, linewidth=2, color='#d14eea', label='$a = 0.06, 0.10$')
plt.plot(t3,y3, linewidth=2, linestyle='dotted', color='#6300ff', label='$a = 0.08$')
plt.xlim(0,12)
plt.minorticks_off()
plt.legend(loc= 'upper left', frameon=True, fontsize=16)
plt.savefig('chap1sec1.3ex11.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 261.16964734231175
# 261.1696473423118
# Failed to find a Ghostscript installation.  Distillation step skipped.

# %% [markdown]
# 20. The most important curve in probability is the bell-shaped graph of $e^{−t/2}$. With a calculator or computer find this function at $t = −2, −1, 0, 1, 2$. Sketch the graph of $e^{−t/2}$ from $t = −\infty$ to $t = \infty$. _It never goes below zero_.

# %%
t = np.arange(-5,5,0.01)
y = np.exp(-np.square(t)/2)

index = [-2,-1,0,1,2]
for i in index:
    print(np.exp(-np.square(i)/2))

plt.figure(figsize=(6,4))
plt.style.use(['science','scatter','dark_background'])
plt.plot(t,y, linewidth=2, color='#00ff9f')
plt.xlim(-5,5)
plt.ylim(0,)
plt.minorticks_off()
plt.savefig('chap1sec1.3ex20.eps', format='eps')
plt.show()
# Out:
# 0.1353352832366127
# 0.6065306597126334
# 1.0
# 0.6065306597126334
# 0.1353352832366127
# Failed to find a Ghostscript installation.  Distillation step skipped.
